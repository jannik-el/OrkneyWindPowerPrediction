# %%
import plotly.express as px
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
import pandas as pd
from tqdm import tqdm
import joblib
import datetime as dt
from sklearn.model_selection import TimeSeriesSplit
from skimpy import skim
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel, RBF

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append('..')
import fx

# %%
data = fx.pull_data(days=90)

# %%
X_train, y_train, X_test, y_test = fx.data_splitting(data, output_val="Non-ANM")

# %%
pipeline = Pipeline(steps=[
    ("col_transformer", ColumnTransformer(transformers=[
        ("Speed", None, ["Speed"]),
        ("Direction", None, ["Direction"]),
        ], remainder="drop")),
    ("model", None)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pipeline = Pipeline(steps=[
#       2     ("col_transformer", ColumnTransformer(transformers=[
#       3         ("Speed", None, ["Speed"]),
#       4         ("Direction", None, ["Direction"]),
#       5         ], remainder="drop")),
#       6     ("model", None)
#       7 ])
#
# NameError: name 'Pipeline' is not defined

# %%
X_test
# Out:
#                                  ANM    Non-ANM      Total Direction  \
# time
# 2023-02-04 12:00:00+00:00  11.439659  11.481322  22.920981         S
# 2023-02-04 15:00:00+00:00  11.556457  11.412967  22.969424         W
# 2023-02-04 18:00:00+00:00  10.810869  11.316783  22.127652       WNW
# 2023-02-04 21:00:00+00:00  11.411241  11.422356  22.833597       WNW
# 2023-02-05 00:00:00+00:00   9.339153  11.124344  20.463497       WNW
# ...                              ...        ...        ...       ...
# 2023-02-18 21:00:00+00:00   2.097053   4.954194   7.051247         W
# 2023-02-19 00:00:00+00:00   4.987375  10.023011  15.010387         W
# 2023-02-19 03:00:00+00:00   5.683093  10.547728  16.230821       WSW
# 2023-02-19 06:00:00+00:00   7.619722  10.629117  18.248839        SW
# 2023-02-19 09:00:00+00:00   9.370757  11.851723  21.222480         S
#
#                           Lead_hours   Source_time     Speed
# time
# 2023-02-04 12:00:00+00:00          1  1.675505e+09  11.17600
# 2023-02-04 15:00:00+00:00          1  1.675516e+09  13.85824
# 2023-02-04 18:00:00+00:00          1  1.675526e+09  12.96416
# 2023-02-04 21:00:00+00:00          1  1.675537e+09  12.96416
# 2023-02-05 00:00:00+00:00          1  1.675548e+09  12.07008
# ...                              ...           ...       ...
# 2023-02-18 21:00:00+00:00          1  1.676747e+09   4.91744
# 2023-02-19 00:00:00+00:00          1  1.676758e+09   8.94080
# 2023-02-19 03:00:00+00:00          1  1.676768e+09  11.17600
# 2023-02-19 06:00:00+00:00          1  1.676779e+09  11.17600
# 2023-02-19 09:00:00+00:00          1  1.676790e+09   9.83488
#
# [119 rows x 7 columns]

# %%
param_grid = {
    'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
    'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
    'model': [
        LinearRegression(), 
        MLPRegressor(hidden_layer_sizes=(150, 150), activation='tanh', solver='sgd'), 
        SVR(kernel='rbf', gamma='scale', C=1.0, epsilon=0.1),
        HuberRegressor(epsilon=1.35, alpha=0.0001),
        RANSACRegressor(min_samples=0.1, max_trials=100),
        GaussianProcessRegressor(alpha=0.1, kernel=RBF()) 
    ]
}

# mlp_param_grid = {
#     'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
#     'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
#     'model': [MLPRegressor()],
#     'model__hidden_layer_sizes': [(150, 150),(250, 250)],
#     'model__activation': ['tanh'],
#     'model__solver': ['sgd']
# }

# svr_param_grid = {
#     'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
#     'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
#     'model': [SVR(kernel='rbf')],
# }

# huber_param_grid = {
#     'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
#     'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
#     'model': [HuberRegressor()],
#     'model__epsilon': [1.35, 1.5, 1.75],
#     'model__alpha': [0.0001, 0.001, 0.01],
# }

# ransac_param_grid = {
#     'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
#     'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
#     'model': [RANSACRegressor()],
#     'model__min_samples': [0.1, 0.2, 0.3],
#     'model__max_trials': [100, 200, 300],
# }

# gpr_param_grid = {
#     'col_transformer__Speed': [None, StandardScaler(), PolynomialFeatures(), fx.EmpiricalWaveletTransform(level=5)],
#     'col_transformer__Direction': ["drop", fx.WindDirectionMapper(), fx.CompassToCartesianTransformer()],
#     'model': [GaussianProcessRegressor()],
#     'model__alpha': [0.1, 0.5, 1.0],
#     'model__kernel': [RBF(), DotProduct(), WhiteKernel()],
# }

# create transformer which converts wind direction and speed to imaginary number

# %%
# param_grids = {"Linear Regression": param_grid, "MLP Regressor": mlp_param_grid, "SVR": svr_param_grid, "Huber Regressor": huber_param_grid, "RANSAC Regressor": ransac_param_grid, "Gaussian Process Regressor": gpr_param_grid}

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
GS = GridSearchCV(pipeline, param_grid, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
GS.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=Pipeline(steps=[('col_transformer',
#                                         ColumnTransformer(transformers=[('Speed',
#                                                                          None,
#                                                                          ['Speed']),
#                                                                         ('Direction',
#                                                                          None,
#                                                                          ['Direction'])])),
#                                        ('model', None)]),
#              n_jobs=-1,
#              param_grid={'col_transformer__Direction': ['drop',
#                                                         WindDirectionMapper(),
#                                                         CompassToCartesianTransformer...
#                          'col_transformer__Speed': [None, StandardScaler(),
#                                                     PolynomialFeatures(),
#                                                     EmpiricalWaveletTransform()],
#                          'model': [LinearRegression(),
#                                    MLPRegressor(activation='tanh',
#                                                 hidden_layer_sizes=(150, 150),
#                                                 solver='sgd'),
#                                    SVR(), HuberRegressor(),
#                                    RANSACRegressor(min_samples=0.1),
#                                    GaussianProcessRegressor(alpha=0.1,
#                                                             kernel=RBF(length_scale=1))]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
pd.DataFrame(GS.cv_results_).sort_values(by='mean_test_score', ascending=False).head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 55       0.950269      0.555540         0.009399        0.003720
# 60       0.017198      0.006941         0.009402        0.004927
# 63       0.037800      0.002639         0.007801        0.001327
# 12       0.010000      0.001898         0.004999        0.000895
# 11       0.475027      0.436317         0.008400        0.002245
# 56       0.025997      0.011023         0.012800        0.002040
# 17       0.255827      0.382948         0.011802        0.004534
# 66       0.023000      0.007669         0.011200        0.001832
# 7        0.778428      0.576586         0.006201        0.001167
# 69       0.049802      0.020088         0.018802        0.016618
#
#    param_col_transformer__Direction param_col_transformer__Speed  \
# 55  CompassToCartesianTransformer()             StandardScaler()
# 60  CompassToCartesianTransformer()         PolynomialFeatures()
# 63  CompassToCartesianTransformer()         PolynomialFeatures()
# 12                             drop         PolynomialFeatures()
# 11                             drop             StandardScaler()
# 56  CompassToCartesianTransformer()             StandardScaler()
# 17                             drop         PolynomialFeatures()
# 66  CompassToCartesianTransformer()  EmpiricalWaveletTransform()
# 7                              drop             StandardScaler()
# 69  CompassToCartesianTransformer()  EmpiricalWaveletTransform()
#
#                                           param_model  \
# 55  MLPRegressor(activation='tanh', hidden_layer_s...
# 60                                 LinearRegression()
# 63                                   HuberRegressor()
# 12                                 LinearRegression()
# 11  GaussianProcessRegressor(alpha=0.1, kernel=RBF...
# 56                                              SVR()
# 17  GaussianProcessRegressor(alpha=0.1, kernel=RBF...
# 66                                 LinearRegression()
# 7   MLPRegressor(activation='tanh', hidden_layer_s...
# 69                                   HuberRegressor()
#
#                                                params  split0_test_score  \
# 55  {'col_transformer__Direction': CompassToCartes...         -17.812618
# 60  {'col_transformer__Direction': CompassToCartes...         -23.054782
# 63  {'col_transformer__Direction': CompassToCartes...         -29.334378
# 12  {'col_transformer__Direction': 'drop', 'col_tr...         -35.698316
# 11  {'col_transformer__Direction': 'drop', 'col_tr...         -34.828515
# 56  {'col_transformer__Direction': CompassToCartes...         -38.007182
# 17  {'col_transformer__Direction': 'drop', 'col_tr...         -35.483965
# 66  {'col_transformer__Direction': CompassToCartes...         -29.437625
# 7   {'col_transformer__Direction': 'drop', 'col_tr...         -38.248946
# 69  {'col_transformer__Direction': CompassToCartes...         -27.605741
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 55         -10.880214         -23.036070         -15.872964
# 60         -11.517416         -25.134515         -15.253234
# 63         -11.559704         -25.984217         -16.866358
# 12         -15.686535         -17.656734         -19.538522
# 11         -18.311913         -18.534014         -18.987530
# 56         -12.856233         -24.637864         -17.017648
# 17         -19.246511         -18.848818         -19.322640
# 66         -16.732053         -24.353134         -17.765636
# 7          -17.238489         -17.622277         -19.807867
# 69         -17.919830         -27.716696         -16.903052
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 55         -12.862455       -16.092864        4.214767                1
# 60         -13.943289       -17.780647        5.333612                2
# 63         -14.910012       -19.730934        6.775629                3
# 12         -13.906740       -20.497369        7.831193                4
# 11         -13.154804       -20.763355        7.346453                5
# 56         -12.792784       -21.062342        9.507863                6
# 17         -12.935779       -21.167542        7.552382                7
# 66         -17.952915       -21.248273        4.900817                8
# 7          -14.895027       -21.562521        8.487565                9
# 69         -18.138343       -21.656732        4.920464               10

# %%
def run_pipelines(param_grids, X_train, y_train, X_test, y_test):
    results = []
    models = []
    for name, params in tqdm(param_grids.items()):
        grid_search = GridSearchCV(pipeline, params, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1)
        grid_search.fit(X_train, y_train)
        results.append([name, fx.MSE(grid_search.predict(X_train), y_train), fx.MSE(grid_search.predict(X_test), y_test), grid_search.best_params_])
        models.append(grid_search.best_estimator_)
    return results, models

# %%
def gridsearch_df(param_grids, X_train, y_train, X_test, y_test):
    results = pd.DataFrame()
    for name, params in tqdm(param_grids.items()):
        grid_search = GridSearchCV(pipeline, params, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1)
        grid_search.fit(X_train, y_train)
        results = pd.concat([results, pd.DataFrame(grid_search.cv_results_)])
    return results

# %%
# results = gridsearch_df(param_grids, X_train, y_train, X_test, y_test)

# %%
# results, models = run_pipelines(param_grids, X_train, y_train, X_test, y_test)

# %%
def choose_best_model(results, models):
    # choose best model and save it
    df = pd.DataFrame(results, columns=["Model", "Train MSE", "Test MSE", "Best Params"])
    df = df.sort_values(by="Test MSE")
    best_model = models[df.index[0]]
    name = df["Model"][df.index[0]]
    joblib.dump(best_model, f"{name}-{dt.date.today()}.pkl")
    return df

# %%
# choose_best_model(results, models)

# %%
# best_model = joblib.dump(GS.best_estimator_, f"{dt.date.today()}.pkl")
best_model = GS.best_estimator_

# %%
forecast = fx.load_forecasts()

# load best model
# best_model = joblib.load(r"C:\Users\janni\OneDrive - ITU\Documents\UNI\4Semester\LSDA\Assignments\A1\2023-02-19.pkl")

future = best_model.predict(forecast)
forecast["Power Generation Forecast"] = future
forecast = forecast.resample("3H").mean()
forecast.drop(columns=["Speed", "Source_time"], inplace=True)

test_prediction = best_model.predict(X_test)
test_data = fx.create_timestamps(test_prediction, X_test, y_test)


# combine testforecast and gen_forecast
final_df = pd.concat([test_data, forecast], axis=0)

final_df.columns = ["Model", "Actual", "Forecast"]
final_df
# Out:
#                                Model     Actual   Forecast
# 2023-02-04 12:00:00+00:00  14.853033  11.481322        NaN
# 2023-02-04 15:00:00+00:00  12.103725  11.412967        NaN
# 2023-02-04 18:00:00+00:00  11.989028  11.316783        NaN
# 2023-02-04 21:00:00+00:00  11.989028  11.422356        NaN
# 2023-02-05 00:00:00+00:00  11.808380  11.124344        NaN
# ...                              ...        ...        ...
# 2023-02-23 09:00:00+00:00        NaN        NaN   9.925750
# 2023-02-23 12:00:00+00:00        NaN        NaN  10.885034
# 2023-02-23 15:00:00+00:00        NaN        NaN  11.994987
# 2023-02-23 18:00:00+00:00        NaN        NaN  11.855169
# 2023-02-23 21:00:00+00:00        NaN        NaN  11.898704
#
# [155 rows x 3 columns]

# %%
best_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('Speed', StandardScaler(),
#                                                   ['Speed']),
#                                                  ('Direction',
#                                                   CompassToCartesianTransformer(),
#                                                   ['Direction'])])),
#                 ('model',
#                  MLPRegressor(activation='tanh', hidden_layer_sizes=(150, 150),
#                               solver='sgd'))])

# %%
fx.MSE(best_model.predict(X_test), y_test)
# Out:
# 7.204722221715

# %%
# plot train data and model using px.line
fig = px.line(x=X_train.index, y=y_train, title="Train Data")
fig.add_scatter(x=X_train.index, y=best_model.predict(X_train), mode="lines", name="Model")
fig.show()

# %%
# plot final_df
fig = px.line(final_df, x=final_df.index, y=["Model", "Actual", "Forecast"], title="Power Generation Forecast")
fig.update_xaxes(title_text="Time")
fig.update_yaxes(title_text="Power Generation")
fig.update_layout(legend_title_text="Legend")
fig.show()
